# %%
# %pip install yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (0.2.66)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (from yfinance) (2.3.3)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (from yfinance) (2.2.6)
# Requirement already satisfied: requests>=2.31 in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (from yfinance) (2.32.5)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (from yfinance) (4.5.1)
# Requirement already satisfied: pytz>=2022.5 in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (from yfinance) (2.4.7)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (from yfinance) (3.18.3)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (from yfinance) (4.14.3)
# Requirement already satisfied: curl_cffi>=0.7 in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (from yfinance) (0.14.0)
# Requirement already satisfied: protobuf>=3.19.0 in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (from yfinance) (6.33.2)
# Requirement already satisfied: websockets>=13.0 in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (from yfinance) (15.0.1)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: cffi>=1.12.0 in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (from curl_cffi>=0.7->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (from curl_cffi>=0.7->yfinance) (2025.11.12)
# Requirement already satisfied: pycparser in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.23)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (from pandas>=1.3.0->yfinance) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (from requests>=2.31->yfinance) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (from requests>=2.31->yfinance) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (from requests>=2.31->yfinance) (2.6.1)
# Requirement already satisfied: yfinance in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (0.2.66)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (from yfinance) (2.3.3)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (from yfinance) (2.2.6)
# Requirement already satisfied: requests>=2.31 in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (from yfinance) (2.32.5)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (from yfinance) (4.5.1)
# Requirement already satisfied: pytz>=2022.5 in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (from yfinance) (2.4.7)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (from yfinance) (3.18.3)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (from yfinance) (4.14.3)
# Requirement already satisfied: curl_cffi>=0.7 in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (from yfinance) (0.14.0)
# Requirement already satisfied: protobuf>=3.19.0 in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (from yfinance) (6.33.2)
# Requirement already satisfied: websockets>=13.0 in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (from yfinance) (15.0.1)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: cffi>=1.12.0 in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (from curl_cffi>=0.7->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (from curl_cffi>=0.7->yfinance) (2025.11.12)
# Requirement already satisfied: pycparser in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.23)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (from pandas>=1.3.0->yfinance) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (from requests>=2.31->yfinance) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (from requests>=2.31->yfinance) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (from requests>=2.31->yfinance) (2.6.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (0.14.6)
# Requirement already satisfied: numpy<3,>=1.22.3 in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (from statsmodels) (2.2.6)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (from statsmodels) (1.15.3)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (from statsmodels) (2.3.3)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (from statsmodels) (1.0.2)
# Requirement already satisfied: packaging>=21.3 in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (from statsmodels) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf

# %%
# %pip install torch
# Out:
# Requirement already satisfied: torch in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (2.9.1)
# Requirement already satisfied: filelock in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (from torch) (3.20.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (from torch) (2025.12.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\samkn\.conda\envs\cleanenv\lib\site-packages (from jinja2->torch) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import torch
import pandas as pd 
import matplotlib.pyplot as plt

# %%
nifty50 = yf.download("^NSEI", start="2020-01-01", end="2024-01-01")
# Out:
# C:\Users\samkn\AppData\Local\Temp\ipykernel_22884\3882381510.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   nifty50 = yf.download("^NSEI", start="2020-01-01", end="2024-01-01")
# [*********************100%***********************]  1 of 1 completed

# %%
print(nifty50.head())
# Out:
# Price              Close          High           Low          Open  Volume
# Ticker             ^NSEI         ^NSEI         ^NSEI         ^NSEI   ^NSEI
# Date
# 2020-01-01  12182.500000  12222.200195  12165.299805  12202.150391  304100
# 2020-01-02  12282.200195  12289.900391  12195.250000  12198.549805  407700
# 2020-01-03  12226.650391  12265.599609  12191.349609  12261.099609  428800
# 2020-01-06  11993.049805  12179.099609  11974.200195  12170.599609  396500
# 2020-01-07  12052.950195  12152.150391  12005.349609  12079.099609  447800

# %%
plt.plot(nifty50['Close'])
plt.title("Nifty 50 Closing Prices")
# Out:
# Text(0.5, 1.0, 'Nifty 50 Closing Prices')

# %%
nifty50.dropna(inplace=True)

# %%
nifty50 = np.log(nifty50)
# Out:
# c:\Users\samkn\.conda\envs\cleanenv\lib\site-packages\pandas\core\internals\blocks.py:395: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)

# %%
plt.plot(nifty50['Close'])

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
acf = plot_acf(nifty50['Close'])
pacf = plot_pacf(nifty50['Close'])

# %%
from statsmodels.tsa.stattools import adfuller
result = adfuller(nifty50['Close'])
print('ADF Statistic:', result[0])
# Out:
# ADF Statistic: -0.6852035507886176

# %%
x_train = nifty50['Close'][:int(len(nifty50['Close'])*0.8)]
x_test = nifty50['Close'][int(len(nifty50['Close'])*0.8):]

# %%
x_train_diff = x_train.diff(1).dropna()
x_test_diff = x_test.diff(1).dropna()
plt.plot(x_train_diff)
plt.title("Differenced Nifty 50 Closing Prices - Training Set")
plt.plot(x_test_diff)
plt.title("Differenced Nifty 50 Closing Prices - Test Set")
# Out:
# Text(0.5, 1.0, 'Differenced Nifty 50 Closing Prices - Test Set')

# %%
acf_train = plot_acf(x_train_diff)
pacf_train = plot_pacf(x_train_diff)

# %%
adf_x_train_diff = adfuller(x_train_diff)
print('ADF Statistic for Differenced Data:', adf_x_train_diff[0])
# Out:
# ADF Statistic for Differenced Data: -8.16205081775001

# %%
import pmdarima as pm
auto_model = pm.auto_arima(x_train, stepwise=False, seasonal=False, trace=True)
print(auto_model.summary())
# Out:
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-4499.276, Time=0.18 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-4501.323, Time=0.17 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=-4499.880, Time=0.71 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=-4498.948, Time=0.87 sec
#  ARIMA(0,1,4)(0,0,0)[0] intercept   : AIC=-4498.398, Time=1.73 sec
#  ARIMA(0,1,5)(0,0,0)[0] intercept   : AIC=-4517.091, Time=1.84 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-4501.514, Time=0.49 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-4499.637, Time=0.39 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=-4497.840, Time=0.82 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=-4504.050, Time=1.39 sec
#  ARIMA(1,1,4)(0,0,0)[0] intercept   : AIC=-4500.214, Time=1.55 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=-4499.754, Time=0.36 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=-4497.790, Time=1.09 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-4495.820, Time=1.10 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=-4502.873, Time=1.26 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=-4498.679, Time=0.28 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=-4496.738, Time=0.87 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=-4494.654, Time=1.00 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : AIC=-4497.110, Time=1.30 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=-4495.364, Time=0.72 sec
#  ARIMA(5,1,0)(0,0,0)[0] intercept   : AIC=-4523.007, Time=1.69 sec
#
# Best model:  ARIMA(5,1,0)(0,0,0)[0] intercept
# Total fit time: 19.845 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  792
# Model:               SARIMAX(5, 1, 0)   Log Likelihood                2268.503
# Date:                Wed, 31 Dec 2025   AIC                          -4523.007
# Time:                        19:08:47   BIC                          -4490.294
# Sample:                             0   HQIC                         -4510.433
#                                 - 792
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0004      0.001      0.669      0.504      -0.001       0.002
# ar.L1         -0.0775      0.024     -3.215      0.001      -0.125      -0.030
# ar.L2          0.0136      0.017      0.791      0.429      -0.020       0.047
# ar.L3          0.0322      0.020      1.651      0.099      -0.006       0.070
# ar.L4          0.0371      0.022      1.656      0.098      -0.007       0.081
# ar.L5          0.1867      0.020      9.167      0.000       0.147       0.227
# sigma2         0.0002   4.41e-06     42.806      0.000       0.000       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.53   Jarque-Bera (JB):              5390.28
# Prob(Q):                              0.47   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.30   Skew:                            -0.99
# Prob(H) (two-sided):                  0.00   Kurtosis:                        15.63
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
from statsmodels.tsa.arima.model import ARIMA
model = ARIMA(x_train, order=(5,1,0))
model_fit = model.fit()
print(model_fit.summary())
# Out:
# c:\Users\samkn\.conda\envs\cleanenv\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\samkn\.conda\envs\cleanenv\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\samkn\.conda\envs\cleanenv\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  ^NSEI   No. Observations:                  792
# Model:                 ARIMA(5, 1, 0)   Log Likelihood                2268.191
# Date:                Wed, 31 Dec 2025   AIC                          -4524.381
# Time:                        19:08:47   BIC                          -4496.342
# Sample:                             0   HQIC                         -4513.604
#                                 - 792
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0765      0.024     -3.188      0.001      -0.124      -0.029
# ar.L2          0.0147      0.016      0.902      0.367      -0.017       0.047
# ar.L3          0.0332      0.019      1.742      0.081      -0.004       0.071
# ar.L4          0.0381      0.022      1.710      0.087      -0.006       0.082
# ar.L5          0.1876      0.020      9.216      0.000       0.148       0.227
# sigma2         0.0002   4.39e-06     43.065      0.000       0.000       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.49   Jarque-Bera (JB):              5368.35
# Prob(Q):                              0.48   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.30   Skew:                            -0.98
# Prob(H) (two-sided):                  0.00   Kurtosis:                        15.61
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
print(list(model_fit.forecast(steps=len(x_test))))
# Out:
# [9.786122831332769, 9.785449583772019, 9.788787579787956, 9.789916622980627, 9.790377362950068, 9.790769267536664, 9.79078458994897, 9.791473710084686, 9.79166359270421, 9.791761067415216, 9.79185340332161, 9.791883237396323, 9.792022061750348, 9.79205428267192, 9.792076654011021, 9.792098488533217, 9.792109108347304, 9.79213663035002, 9.792142303417835, 9.79214765579174, 9.792152745230117, 9.792155664740923, 9.792161073093968, 9.792162139597634, 9.79216343259497, 9.792164595140305, 9.792165314547264, 9.792166374754775, 9.79216659220678, 9.792166901936753, 9.792167162184452, 9.792167329432298, 9.7921675379248, 9.792167585680776, 9.792167658674222, 9.792167715917603, 9.792167753521616, 9.792167794842639, 9.79216780587788, 9.792167822765988, 9.792167835181456, 9.792167843476147, 9.792167851757219, 9.79216785437218, 9.792167858210894, 9.792167860876127, 9.792167862687272, 9.792167864368562, 9.79216786499203, 9.792167865850953, 9.792167866419303, 9.792167866813019, 9.792167867158952, 9.792167867306866, 9.792167867496513, 9.792167867617302, 9.792167867702808, 9.792167867774877, 9.792167867809612, 9.792167867851036, 9.792167867876692, 9.79216786789528, 9.792167867910456, 9.792167867918517, 9.792167867927489, 9.792167867932946, 9.792167867936994, 9.792167867940217, 9.792167867942066, 9.792167867943999, 9.792167867945164, 9.792167867946047, 9.792167867946736, 9.792167867947155, 9.792167867947569, 9.792167867947818, 9.792167867948011, 9.792167867948159, 9.792167867948253, 9.792167867948342, 9.792167867948395, 9.792167867948438, 9.79216786794847, 9.792167867948491, 9.79216786794851, 9.792167867948523, 9.792167867948532, 9.792167867948539, 9.792167867948544, 9.792167867948548, 9.79216786794855, 9.792167867948551, 9.792167867948553, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555, 9.792167867948555]
# c:\Users\samkn\.conda\envs\cleanenv\lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\samkn\.conda\envs\cleanenv\lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(

# %%
forecast = model_fit.forecast(steps=len(x_test))
nifty50['forecast'] = [None]*len(x_train) + list(forecast)
nifty50.plot(y=['Close', 'forecast'])
# Out:
# c:\Users\samkn\.conda\envs\cleanenv\lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# <Axes: xlabel='Date'>

# %%
nifty50['forecast']= np.exp(nifty50['forecast'])
nifty50['Close']= np.exp(nifty50['Close'])
nifty50.plot(y=['Close', 'forecast'])
# Out:
# <Axes: xlabel='Date'>

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, root_mean_squared_error
mse = mean_squared_error(np.exp(x_test), nifty50['forecast'][len(x_train):])
mae = mean_absolute_error(np.exp(x_test), nifty50['forecast'][len(x_train):])
rmse = root_mean_squared_error(np.exp(x_test), nifty50['forecast'][len(x_train):])
print(f'MSE: {mse}, MAE: {mae}, RMSE: {rmse}')
# Out:
# MSE: 2741540.0378070283, MAE: 1411.3619870134582, RMSE: 1655.7596558096916
